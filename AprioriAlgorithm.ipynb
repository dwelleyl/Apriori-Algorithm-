# %% [markdown]
# # CSC 4601 - Final Project
#
# ## Apriori Algorithm
#
# Kelsey Collins and Lauren Dwelley

# %%
#!pip install mlxtend

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
#loading dataset into a dataframe 

market_pd = pd.read_csv('Market_Basket_Optimisation.csv')
market_data = pd.DataFrame(market_pd)

# %%
#generating frequent itemsets 

#frequent_itemsets = apriori(market_data, min_support=0.5, use_colnames=True)
